# %%
if __name__ == "__main__":
    u = set("abcdefghijklmnpoqrstuvwxyz")
    
    a = {"a", "b", "h", "j", "l"}
    b = {"b", "c", "h", "l", "r", "v"}
    c = {"j", "k", "n", "t", "z"}
    d = {"b", "i", "k", "v", "w"}
    
    
    
    x = (a.union(b)).intersection(c)
    print(f"x = {x}")
    
    an = u.difference(a)
    bn = u.difference(b)
    
    y = (an.intersection(bn)).difference(c.union(d))
    print(f"y = {y}")
# Out:
# x = {'j'}
# y = {'u', 'd', 'o', 'y', 'g', 'x', 'q', 'e', 's', 'm', 'p', 'f'}

# %% [markdown]
# ![%D0%91%D0%B5%D0%B7%D1%8B%D0%BC%D1%8F%D0%BD%D0%BD%D1%8B%D0%B9.jpg](attachment:%D0%91%D0%B5%D0%B7%D1%8B%D0%BC%D1%8F%D0%BD%D0%BD%D1%8B%D0%B9.jpg)
